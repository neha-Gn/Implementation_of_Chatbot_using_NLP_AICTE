# %% [markdown]
# # CHATBOT

# %%
pip install nltk scikit-learn streamlit
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Importing all the necessary libraries
import nltk
import random
import os
import ssl
import streamlit as st
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# %%
ssl._create_defult_https_context = ssl._create_unverified_context
nltk.data.path.append(os.path.abspath('nltk_data'))
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\nehag\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# All the patterns and response
{
  "intents": [
    {
      "tag": "greeting",
      "patterns": ["Hi", "Hello", "Hey", "How are you?", "What's up?", "Greetings", "Hi there!", "Good morning", "Good afternoon"],
      "responses": ["Hello! How can I assist you today?", "Hey there! How can I help with your web development needs?", "Hi! What can I do for you today?"]
    },
    {
      "tag": "about_us",
      "patterns": ["What can you do?", "Who are you?", "What services do you provide?", "Tell me about your company", "What is your expertise?"],
      "responses": ["We are a full-stack development freelancing startup offering web, mobile, and cloud-based solutions.", "We specialize in frontend, backend, API development, and cloud deployment.", "Our team builds scalable web applications using the latest technologies."]
    },
    {
      "tag": "services",
      "patterns": ["What services do you offer?", "Do you build web apps?", "Can you create an e-commerce website?", "Do you provide backend development?", "What kind of websites do you develop?"],
      "responses": ["We offer full-stack web development, backend and frontend solutions, mobile-friendly apps, and API development.", "Our expertise includes frontend (React, Angular), backend (Node.js, Django), and database management.", "We develop dynamic websites, CMS solutions, SaaS platforms, and custom applications."]
    },
    {
      "tag": "technologies",
      "patterns": ["Which technologies do you work with?", "Do you use React and Node?", "What programming languages do you use?", "Do you work with Django?", "What frameworks do you specialize in?"],
      "responses": ["We specialize in MERN Stack, MEAN Stack, Django, Flask, and cloud-based full-stack solutions.", "Our team works with JavaScript (React, Angular, Vue), Python, PHP, and cloud platforms.", "We also handle DevOps, cloud computing, and database management."]
    },
    {
      "tag": "pricing",
      "patterns": ["How much does a website cost?", "What are your rates for web development?", "Can I get a price estimate?", "Do you charge hourly or fixed price?", "What is your development pricing model?"],
      "responses": ["Pricing depends on the project complexity. Can you share more details for an estimate?", "We offer flexible pricing—hourly rates, fixed project costs, and retainers. Let's discuss your project!", "Every project is unique. Contact us to get a tailored quote."]
    },
    {
      "tag": "portfolio",
      "patterns": ["Can I see your portfolio?", "Show me your past work", "Do you have examples of your projects?", "Can I check your case studies?", "What projects have you completed?"],
      "responses": ["We have worked on a variety of projects across different industries. You can explore them on our website!", "Our past projects include e-commerce sites, SaaS platforms, and custom web applications. Check our website for details!"]
    },
    {
      "tag": "booking",
      "patterns": ["Can I book a meeting?", "I want to talk to a developer", "Schedule a consultation", "Can I set up a call with you?", "How do I book a consultation?"],
      "responses": ["We'd love to discuss your project! You can find consultation details on our website.", "You can easily schedule a call with us. Just head over to the contact section of our website!"]
    },
    {
      "tag": "collaboration",
      "patterns": ["Do you collaborate with other developers?", "Can we work together on a project?", "Do you accept partnership requests?", "Are you open to joint ventures?"],
      "responses": ["We are open to collaborations! If you have a proposal, feel free to reach out through our website.", "We love partnering with other professionals. Let's discuss how we can work together!"]
    },
    {
      "tag": "support",
      "patterns": ["I need help with my website", "My website is broken", "Can you fix a bug?", "Do you provide maintenance services?", "Do you offer website support?"],
      "responses": ["We provide website maintenance and support services. Can you describe the issue?", "Our team can troubleshoot and fix technical issues. Let us know how we can assist!"]
    },
    {
      "tag": "SEO",
      "patterns": ["Do you provide SEO services?", "Can you improve my website ranking?", "Do you offer digital marketing?", "Can you optimize my website for Google?"],
      "responses": ["Yes! We offer SEO-friendly web development to improve your site's ranking.", "Our websites are optimized for performance and search engine visibility."]
    },
    {
      "tag": "database_management",
      "patterns": ["Do you work with databases?", "Can you set up a database for my app?", "Do you use MySQL or MongoDB?", "Can you handle database migrations?"],
      "responses": ["We work with relational and NoSQL databases like MySQL, PostgreSQL, MongoDB, and Firebase.", "Our team provides database architecture, migration, and performance optimization."]
    },
    {
      "tag": "security",
      "patterns": ["Do you implement security measures?", "Can you secure my website?", "Do you offer cybersecurity solutions?", "How do you prevent hacking?"],
      "responses": ["Yes! We implement security best practices, including encryption, authentication, and vulnerability assessments.", "Our security measures include SSL encryption, access controls, and security audits."]
    },
    {
      "tag": "lead_capture",
      "patterns": ["I need a new website", "I need help with web development", "How do I get started?", "I want to launch an online store"],
      "responses": ["Please share your name, email, and project details so we can assist you better.", "Tell us about your project, and we'll help you get started."]
    },
    {
      "tag": "follow_up",
      "patterns": ["Any discounts available?", "Do you have special offers?", "Are there any deals?", "Do you have a referral program?"],
      "responses": ["We have special discounts and offers. Subscribe to our newsletter for updates!", "We offer discounts for long-term collaborations and referrals."]
    },
       {
      "tag": "goodbye",
      "patterns": ["Bye", "See you later", "Goodbye", "Take care", "Catch you later", "I’m leaving now"],
      "responses": ["Goodbye! Feel free to reach out anytime.", "Take care! Looking forward to working with you.", "See you soon! Have a great day!"]
    }
  ]
}
# Out:
# {'intents': [{'tag': 'greeting',
#    'patterns': ['Hi',
#     'Hello',
#     'Hey',
#     'How are you?',
#     "What's up?",
#     'Greetings',
#     'Hi there!',
#     'Good morning',
#     'Good afternoon'],
#    'responses': ['Hello! How can I assist you today?',
#     'Hey there! How can I help with your web development needs?',
#     'Hi! What can I do for you today?']},
#   {'tag': 'about_us',
#    'patterns': ['What can you do?',
#     'Who are you?',
#     'What services do you provide?',
#     'Tell me about your company',
#     'What is your expertise?'],
#    'responses': ['We are a full-stack development freelancing startup offering web, mobile, and cloud-based solutions.',
#     'We specialize in frontend, backend, API development, and cloud deployment.',
#     'Our team builds scalable web applications using the latest technologies.']},
#   {'tag': 'services',
#    'patterns': ['What services do you offer?',
#     'Do you build web apps?',
# ...
